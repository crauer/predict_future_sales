# %%
import gc
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import statsmodels.api as sm

from calendar import monthrange
from googletrans import Translator

from itertools import product 

from xgboost import XGBRegressor
from xgboost import plot_importance

# %matplotlib inline

pd.set_option('display.max_colwidth', 500)
pd.set_option('display.max_rows', 500)

# %%
data_df = pd.read_csv('./data/sales_train.csv')
print('Data rows:  {:,}'.format(len(data_df)))

data_df['date'] = pd.to_datetime(data_df['date'], format='%d.%m.%Y')

# Let's break up the date field into constituent pieces.
data_df['date (year)'] = data_df['date'].dt.year
data_df['date (month)'] = data_df['date'].dt.month
data_df['date (days in month)'] = data_df['date'].apply(lambda x: monthrange(x.year, x.month)[1])

data_df.head(2).transpose()
# Out:
# Data rows:  2,935,849
#                                         0                    1
# date                  2013-01-02 00:00:00  2013-01-03 00:00:00
# date_block_num                          0                    0
# shop_id                                59                   25
# item_id                             22154                 2552
# item_price                            999                  899
# item_cnt_day                            1                    1
# date (year)                          2013                 2013
# date (month)                            1                    1
# date (days in month)                   31                   31

# %%
data_df = data_df[
    (data_df['item_price'] >= 0) &
    (data_df['item_price'] < 100000)
]
print('Data rows:  {:,}'.format(len(data_df)))
# Out:
# Data rows:  2,935,847

# %%
test_df = pd.read_csv('./data/test.csv')
print('Test rows:  {:,}'.format(len(test_df)))

# Fixed values.
test_df['date_block_num'] = 34
test_df['date (year)'] = 2015
test_df['date (month)'] = 11
test_df['date (days in month)'] = 30

# Update the prices with the latest month's prices.
last_month_df = data_df[data_df['date_block_num'] == 33][['shop_id', 'item_id', 'item_price']]

test_df = test_df.merge(last_month_df, on=['shop_id', 'item_id'], how='left')

test_df = test_df.drop_duplicates('ID', keep='first')

print('Test rows (after merge):  {:,}'.format(len(test_df)))

test_df[test_df['item_price'] > 0].head(2).T
# Out:
# Test rows:  214,200
# Test rows (after merge):  214,200
#                            2       5
# ID                       2.0     5.0
# shop_id                  5.0     5.0
# item_id               5233.0  5039.0
# date_block_num          34.0    34.0
# date (year)           2015.0  2015.0
# date (month)            11.0    11.0
# date (days in month)    30.0    30.0
# item_price            1199.0  1499.0

# %% [markdown]
# Are there shop/items pairs in the test set that don't exist in the training set?  Yes, so let's load a pre-crafted dataset of shop/item pairs with default data.

# %%
missing_df = pd.read_csv('./data/train_missing2.csv')
print('Missing shop/item pairs:  {:,}'.format(len(missing_df)))

missing_df.head(5)
# Out:
# Missing shop/item pairs:  205,592
#    date_block_num        date  date (year)  date (month)  \
# 0              32  2015-09-01         2015             9
# 1              33  2015-10-01         2015            10
# 2              32  2015-09-01         2015             9
# 3              33  2015-10-01         2015            10
# 4              32  2015-09-01         2015             9
#
#    date (days in month)  shop_id  item_id  item_price  item_cnt_day
# 0                    30        5     5320           0             0
# 1                    31        5     5320           0             0
# 2                    30        5     5268           0             0
# 3                    31        5     5268           0             0
# 4                    30        5     5003           0             0

# %%
data_df = pd.concat([data_df, missing_df, test_df], ignore_index=True, sort=False)

print('Rows:  {:,}'.format(len(data_df)))
# Out:
# Rows:  3,355,639

# %%
data_df.loc[data_df.shop_id == 0, 'shop_id'] = 57
# Якутск ТЦ "Центральный"
data_df.loc[data_df.shop_id == 1, 'shop_id'] = 58
# Жуковский ул. Чкалова 39м²
data_df.loc[data_df.shop_id == 11, 'shop_id'] = 10
# РостовНаДону ТРК "Мегацентр Горизонт" Островной
data_df.loc[data_df.shop_id == 40, 'shop_id'] = 39

# %%
items_df = pd.read_csv('./data/items.csv')
print('Items:  {:,}'.format(len(items_df)))

items_df['item_id'] = items_df['item_id'].astype(int)
items_df['item_category_id'] = items_df['item_category_id'].astype(int)

items_df.head(3)
# Out:
# Items:  22,170
#                                                               item_name  \
# 0                             ! ВО ВЛАСТИ НАВАЖДЕНИЯ (ПЛАСТ.)         D
# 1  !ABBYY FineReader 12 Professional Edition Full [PC, Цифровая версия]
# 2                         ***В ЛУЧАХ СЛАВЫ   (UNV)                    D
#
#    item_id  item_category_id
# 0        0                40
# 1        1                76
# 2        2                40

# %%
item_categories_df = pd.read_csv('./data/item_categories.csv')
print('Item Categories:  {:,}'.format(len(item_categories_df)))

item_categories_df['item_category_id'] = item_categories_df['item_category_id'].astype(int)

translator = Translator()

#item_categories_df['item_category_name (english)'] = item_categories_df['item_category_name'].apply(lambda x: translator.translate(x).text)

# Following english categories were taken from the output file written above.
def get_english_category(x):
    if 0 <= x <= 7:
        return 'Accessories'
    elif 10 <= x <= 17:
        return 'Game Consoles'
    elif 18 <= x <= 31:
        return 'Games'
    elif 32 <= x <= 36:
        return 'Gift Cards'
    elif 37 <= x <= 41:
        return 'Movies'
    elif 42 <= x <= 54:
        return 'Books'
    elif 55 <= x <= 60:
        return 'Music'
    elif 61 <= x <= 72:
        return 'Gifts'
    elif 73 <= x <= 79:
        return 'Software'
    else:
        return 'Misc'
    
item_categories_df['cat_name (normalized)'] = item_categories_df['item_category_id'].apply(lambda x: get_english_category(x))
item_categories_df['cat_name (normalized)'] = item_categories_df['cat_name (normalized)'].astype('category')
item_categories_df['cat_name (code)'] = item_categories_df['cat_name (normalized)'].cat.codes

item_categories_df['category_type'] = item_categories_df['item_category_name'].str.split('-').apply(lambda x: x[0].strip())
item_categories_df['category_type'] = item_categories_df['category_type'].astype('category')
item_categories_df['category_type'] = item_categories_df['category_type'].cat.codes

item_categories_df['category_subtype'] = item_categories_df['item_category_name'].str.split('-').apply(lambda x: x[1].strip() if len(x) > 1 else x[0].strip())
item_categories_df['category_subtype'] = item_categories_df['category_subtype'].astype('category')
item_categories_df['category_subtype'] = item_categories_df['category_subtype'].cat.codes

item_categories_df.head(3)
# Out:
# Item Categories:  84
#         item_category_name  item_category_id cat_name (normalized)  \
# 0  PC - Гарнитуры/Наушники                 0           Accessories
# 1         Аксессуары - PS2                 1           Accessories
# 2         Аксессуары - PS3                 2           Accessories
#
#    cat_name (code)  category_type  category_subtype
# 0                0              0                29
# 1                0              1                 9
# 2                0              1                10

# %%
shops_df = pd.read_csv('./data/shops.csv')
print('Shop rows:  {:,}'.format(len(shops_df)))

shops_df['shop_id'] = shops_df['shop_id'].astype(int)
#shops_df['shop_name (english)'] = shops_df['shop_name'].apply(lambda x: translator.translate(x).text)

shops_df['shop_loc'] = shops_df['shop_name'].apply(lambda x: str(x).split(' ')[0]).astype('category')
shops_df['shop_loc (code)'] = shops_df['shop_loc'].cat.codes

shops_df.head(3)
# Out:
# Shop rows:  60
#                        shop_name  shop_id shop_loc  shop_loc (code)
# 0  !Якутск Орджоникидзе, 56 фран        0  !Якутск                0
# 1  !Якутск ТЦ "Центральный" фран        1  !Якутск                0
# 2               Адыгея ТЦ "Мега"        2   Адыгея                1

# %%
monthly_df = data_df.groupby(['shop_id', 'item_id', 'date_block_num']).agg({'item_cnt_day': 'sum'}).reset_index()
monthly_df.columns = ['shop_id', 'item_id', 'date_block_num', 'item_cnt_month']

# %%
print('Training before merge:  {:,}'.format(len(data_df)))

data_df = data_df.merge(monthly_df, on=['shop_id', 'item_id', 'date_block_num'], how='left')
data_df = data_df.fillna(0)

data_df = data_df.merge(items_df[['item_id', 'item_category_id']], on='item_id', how='left')
data_df = data_df.merge(item_categories_df[['item_category_id', 'cat_name (code)', 'category_type', 'category_subtype']], 
                        on='item_category_id', 
                        how='left')
data_df = data_df.merge(shops_df[['shop_id', 'shop_loc (code)']], on='shop_id', how='left')

data_df['date_block_num'] = data_df['date_block_num'].astype('int')
data_df['shop_id'] = data_df['shop_id'].astype('int')
data_df['item_id'] = data_df['item_id'].astype('int')
data_df['item_category_id'] = data_df['item_category_id'].astype('int')
data_df['date (year)'] = data_df['date (year)'].astype('int')
data_df['date (month)'] = data_df['date (month)'].astype('int')
data_df['date (days in month)'] = data_df['date (days in month)'].astype('int')

data_df['item_cnt_month'] = data_df['item_cnt_month'].clip(0 ,20)

print('Training after merge:  {:,}'.format(len(data_df)))

# Drop the daily columns that aren't needed.
data_df = data_df.drop(['date', 'item_cnt_day'], axis=1)

data_df.head(2).T
# Out:
# Training before merge:  3,355,639
# Training after merge:  3,355,639
#                             0       1
# date_block_num            0.0     0.0
# shop_id                  59.0    25.0
# item_id               22154.0  2552.0
# item_price              999.0   899.0
# date (year)            2013.0  2013.0
# date (month)              1.0     1.0
# date (days in month)     31.0    31.0
# ID                        0.0     0.0
# item_cnt_month            1.0     0.0
# item_category_id         37.0    58.0
# cat_name (code)           7.0     8.0
# category_type            11.0    13.0
# category_subtype          1.0    27.0
# shop_loc (code)          31.0    14.0

# %%
float_cols = [col for col in data_df if data_df[col].dtype == 'float64']
int_cols = [col for col in data_df if data_df[col].dtype in ['int64', 'int32']]

data_df[float_cols] = data_df[float_cols].astype(np.float32)
data_df[int_cols] = data_df[int_cols].astype(np.int16)

# %%
#data_df = data_df[
#    (data_df['shop_id'].isin(test_df['shop_id'].unique())) &
#    (data_df['item_id'].isin(test_df['item_id'].unique()))
#]
#print('Training after removing shops/items not in the test set:  {:,}'.format(len(data_df)))
# Out:
# Training after removing shops/items not in the test set:  1,650,704

# %%
data_df = data_df[
    (data_df['item_cnt_month'] >= 0) &
    (data_df['item_cnt_month'] < 1000)
]
print('Training after clipping (0, 1000) on the target variable:  {:,}'.format(len(data_df)))
# Out:
# Training after clipping (0, 1000) on the target variable:  1,650,704

# %%
data_df['date (holiday season)'] = data_df['date (month)'].apply(lambda x: 1 if x == 12 else 0)

# %%
data_df['item_price (unit)'] = data_df['item_price'] // data_df['item_cnt_month']

# %%
data_df['shop (first sale)'] = data_df['date_block_num'] - data_df.groupby(['item_id', 'shop_id'])['date_block_num'].transform('min')

# %%
# Item count by date_block_num
grouped_df = data_df.groupby(['date_block_num']).agg({'item_cnt_month': ['mean']}).reset_index()
grouped_df.columns = ['date_block_num', 'item_cnt_mef (date_block_num)']

print(grouped_df.head(3))
print('')

data_df = pd.merge(data_df, grouped_df, on=['date_block_num'], how='left')
print('Rows after merge:  {:,}'.format(len(data_df)))

# Item count by month
grouped_df = data_df.groupby(['date (month)']).agg({'item_cnt_month': ['mean']}).reset_index()
grouped_df.columns = ['date (month)', 'item_cnt_mef (month)']

print(grouped_df.head(3))
print('')

data_df = pd.merge(data_df, grouped_df, on=['date (month)'], how='left')
print('Rows after merge:  {:,}'.format(len(data_df)))
print('')

# Item count by year
grouped_df = data_df.groupby(['date (year)']).agg({'item_cnt_month': ['mean']}).reset_index()
grouped_df.columns = ['date (year)', 'item_cnt_mef (year)']

print(grouped_df.head(3))
print('')

data_df = pd.merge(data_df, grouped_df, on=['date (year)'], how='left')
print('Rows after merge:  {:,}'.format(len(data_df)))
print('')

# Item count by item_category, date_block_num
grouped_df = data_df.groupby(['date_block_num', 'item_category_id']).agg({'item_cnt_month': ['mean']}).reset_index()
grouped_df.columns = ['date_block_num', 'item_category_id', 'item_cat_cnt_mef (date_block_num)']

print(grouped_df.head(3))
print('')

data_df = pd.merge(data_df, grouped_df, on=['date_block_num', 'item_category_id'], how='left')
print('Rows after merge:  {:,}'.format(len(data_df)))

# Item count by item_category, month
grouped_df = data_df.groupby(['date (month)', 'item_category_id']).agg({'item_cnt_month': ['mean']}).reset_index()
grouped_df.columns = ['date (month)', 'item_category_id', 'item_cat_cnt_mef (month)']

print(grouped_df.head(3))
print('')

data_df = pd.merge(data_df, grouped_df, on=['date (month)', 'item_category_id'], how='left')
print('Rows after merge:  {:,}'.format(len(data_df)))

# Item count by cat (code), month
grouped_df = data_df.groupby(['date (month)', 'cat_name (code)']).agg({'item_cnt_month': ['mean']}).reset_index()
grouped_df.columns = ['date (month)', 'cat_name (code)', 'cat_name_cnt_mef (month)']

print(grouped_df.head(3))
print('')

data_df = pd.merge(data_df, grouped_df, on=['date (month)', 'cat_name (code)'], how='left')
print('Rows after merge:  {:,}'.format(len(data_df)))

# Item count by cat (code), shop, month
grouped_df = data_df.groupby(['date (month)', 'shop_id', 'cat_name (code)']).agg({'item_cnt_month': ['mean']}).reset_index()
grouped_df.columns = ['date (month)', 'cat_name (code)', 'shop_id', 'cat_name_shop_cnt_mef (month)']

print(grouped_df.head(3))
print('')

data_df = pd.merge(data_df, grouped_df, on=['date (month)', 'shop_id', 'cat_name (code)'], how='left')
print('Rows after merge:  {:,}'.format(len(data_df)))

# Item count by cat (code), shop, date_block_num
grouped_df = data_df.groupby(['date_block_num', 'shop_id', 'cat_name (code)']).agg({'item_cnt_month': ['mean']}).reset_index()
grouped_df.columns = ['date_block_num', 'cat_name (code)', 'shop_id', 'cat_name_shop_cnt_mef (date_block_num)']

print(grouped_df.head(3))
print('')

data_df = pd.merge(data_df, grouped_df, on=['date_block_num', 'shop_id', 'cat_name (code)'], how='left')
print('Rows after merge:  {:,}'.format(len(data_df)))

# Item count by shop_loc, date_block_num
grouped_df = data_df.groupby(['date_block_num', 'shop_loc (code)']).agg({'item_cnt_month': ['mean']}).reset_index()
grouped_df.columns = ['date_block_num', 'shop_loc (code)', 'shop_loc_cnt_mef (date_block_num)']

print(grouped_df.head(3))
print('')

data_df = pd.merge(data_df, grouped_df, on=['date_block_num', 'shop_loc (code)'], how='left')
print('Rows after merge:  {:,}'.format(len(data_df)))

# Item count by shop_loc, item, date_block_num
grouped_df = data_df.groupby(['date_block_num', 'shop_loc (code)', 'item_id']).agg({'item_cnt_month': ['mean']}).reset_index()
grouped_df.columns = ['date_block_num', 'shop_loc (code)', 'item_id', 'shop_loc_item_cnt_mef (date_block_num)']

print(grouped_df.head(3))
print('')

data_df = pd.merge(data_df, grouped_df, on=['date_block_num', 'shop_loc (code)', 'item_id'], how='left')
print('Rows after merge:  {:,}'.format(len(data_df)))

# Item count by shop_loc, cat (code), date_block_num
grouped_df = data_df.groupby(['date_block_num', 'shop_loc (code)', 'cat_name (code)']).agg({'item_cnt_month': ['mean']}).reset_index()
grouped_df.columns = ['date_block_num', 'shop_loc (code)', 'cat_name (code)', 'shop_loc_cat_cnt_mef (date_block_num)']

print(grouped_df.head(3))
print('')

data_df = pd.merge(data_df, grouped_df, on=['date_block_num', 'shop_loc (code)', 'cat_name (code)'], how='left')
print('Rows after merge:  {:,}'.format(len(data_df)))

# Item count by shop_loc, cat item_category, date_block_num
grouped_df = data_df.groupby(['date_block_num', 'shop_loc (code)', 'item_category_id']).agg({'item_cnt_month': ['mean']}).reset_index()
grouped_df.columns = ['date_block_num', 'shop_loc (code)', 'item_category_id', 'shop_loc_item_cat_cnt_mef (date_block_num)']

print(grouped_df.head(3))
print('')

data_df = pd.merge(data_df, grouped_df, on=['date_block_num', 'shop_loc (code)', 'item_category_id'], how='left')
print('Rows after merge:  {:,}'.format(len(data_df)))

# Item price by item, shop, date_block_num
grouped_df = data_df.groupby(['date_block_num', 'shop_id', 'item_id']).agg({'item_price': ['mean']}).reset_index()
grouped_df.columns = ['date_block_num', 'shop_id', 'item_id', 'shop_item_price (date_block_num)']

print(grouped_df.head(3))
print('')

data_df = pd.merge(data_df, grouped_df, on=['date_block_num', 'shop_id', 'item_id'], how='left')
print('Rows after merge:  {:,}'.format(len(data_df)))

# Item price by item, date_block_num
grouped_df = data_df.groupby(['date_block_num', 'item_id']).agg({'item_price': ['mean']}).reset_index()
grouped_df.columns = ['date_block_num', 'item_id', 'item_price (date_block_num)']

print(grouped_df.head(3))
print('')

data_df = pd.merge(data_df, grouped_df, on=['date_block_num', 'item_id'], how='left')
print('Rows after merge:  {:,}'.format(len(data_df)))

# Item count by category_type
grouped_df = data_df.groupby(['date_block_num', 'category_type']).agg({'item_cnt_month': ['mean']}).reset_index()
grouped_df.columns = ['date_block_num', 'category_type', 'cat_type_item_cnt_month (date_block_num)']

print(grouped_df.head(3))
print('')

data_df = pd.merge(data_df, grouped_df, on=['date_block_num', 'category_type'], how='left')
print('Rows after merge:  {:,}'.format(len(data_df)))

# Item count by category_subtype
grouped_df = data_df.groupby(['date_block_num', 'category_subtype']).agg({'item_cnt_month': ['mean']}).reset_index()
grouped_df.columns = ['date_block_num', 'category_subtype', 'cat_subtype_item_cnt_month (date_block_num)']

print(grouped_df.head(3))
print('')

data_df = pd.merge(data_df, grouped_df, on=['date_block_num', 'category_subtype'], how='left')
print('Rows after merge:  {:,}'.format(len(data_df)))
# Out:
#    date_block_num  item_cnt_mef (date_block_num)
# 0               0                       5.762740
# 1               1                       5.698050
# 2               2                       6.820467
#
# Rows after merge:  1,650,704
#    date (month)  item_cnt_mef (month)
# 0             1              5.453773
# 1             2              5.136602
# 2             3              5.491692
#
# Rows after merge:  1,650,704
#
#    date (year)  item_cnt_mef (year)
# 0         2013             6.339588
# 1         2014             5.676167
# 2         2015             2.272665
#
# Rows after merge:  1,650,704
#
#    date_block_num  item_category_id  item_cat_cnt_mef (date_block_num)
# 0               0                 2                           6.960000
# 1               0                 5                           2.215054
# 2               0                 6                           6.319728
#
# Rows after merge:  1,650,704
#    date (month)  item_category_id  item_cat_cnt_mef (month)
# 0             1                 2                  4.917040
# 1             1                 3                  6.061869
# 2             1                 5                  2.387454
#
# Rows after merge:  1,650,704
#    date (month)  cat_name (code)  cat_name_cnt_mef (month)
# 0             1                0                  5.666739
# 1             1                1                  4.270219
# 2             1                2                  7.678179
#
# Rows after merge:  1,650,704
#    date (month)  cat_name (code)  shop_id  cat_name_shop_cnt_mef (month)
# 0             1                2        0                       3.515464
# 1             1                2        1                       1.000000
# 2             1                2        2                       1.333333
#
# Rows after merge:  1,650,704
#    date_block_num  cat_name (code)  shop_id  \
# 0               0                2        0
# 1               0                2        1
# 2               0                2        3
#
#    cat_name_shop_cnt_mef (date_block_num)
# 0                                4.650000
# 1                                1.000000
# 2                                4.377551
#
# Rows after merge:  1,650,704
#    date_block_num  shop_loc (code)  shop_loc_cnt_mef (date_block_num)
# 0               0                1                           3.117391
# 1               0                2                           2.588889
# 2               0                3                           5.820896
#
# Rows after merge:  1,650,704
#    date_block_num  shop_loc (code)  item_id  \
# 0               0                1       33
# 1               0                1      482
# 2               0                1      491
#
#    shop_loc_item_cnt_mef (date_block_num)
# 0                                     1.0
# 1                                     1.0
# 2                                     1.0
#
# Rows after merge:  1,650,704
#    date_block_num  shop_loc (code)  cat_name (code)  \
# 0               0                1                0
# 1               0                1                1
# 2               0                1                3
#
#    shop_loc_cat_cnt_mef (date_block_num)
# 0                               4.650000
# 1                               1.000000
# 2                               4.377551
#
# Rows after merge:  1,650,704
#    date_block_num  shop_loc (code)  item_category_id  \
# 0               0                1                 2
# 1               0                1                 5
# 2               0                1                 6
#
#    shop_loc_item_cat_cnt_mef (date_block_num)
# 0                                    7.000000
# 1                                    2.000000
# 2                                    2.888889
#
# Rows after merge:  1,650,704
#    date_block_num  shop_id  item_id  shop_item_price (date_block_num)
# 0               0        2       33                             499.0
# 1               0        2      482                            3300.0
# 2               0        2      491                             600.0
#
# Rows after merge:  1,650,704
#    date_block_num  item_id  item_price (date_block_num)
# 0               0       32                   341.539246
# 1               0       33                   488.395355
# 2               0       42                   249.000000
#
# Rows after merge:  1,650,704
#    date_block_num  category_type  cat_type_item_cnt_month (date_block_num)
# 0               0              1                                  6.065513
# 1               0              3                                 19.333334
# 2               0              5                                  5.274448
#
# Rows after merge:  1,650,704
#    date_block_num  category_subtype  \
# 0               0                 0
# 1               0                 1
# 2               0                 2
#
#    cat_subtype_item_cnt_month (date_block_num)
# 0                                     6.003472
# 1                                     3.797834
# 2                                     2.876270
#
# Rows after merge:  1,650,704

# %%
month_lags = [1, 2, 3, 6, 12]

col_lags = [
    'item_cnt_month', 
    'item_price (date_block_num)',
    'shop_item_price (date_block_num)',
    'item_cnt_mef (date_block_num)', 
    'item_cat_cnt_mef (date_block_num)',
    'cat_name_shop_cnt_mef (date_block_num)',
    'shop_loc_cnt_mef (date_block_num)',
    'shop_loc_item_cnt_mef (date_block_num)',
    'shop_loc_item_cat_cnt_mef (date_block_num)',
    'shop_loc_cat_cnt_mef (date_block_num)',
    'cat_type_item_cnt_month (date_block_num)',
    'cat_subtype_item_cnt_month (date_block_num)'
]

for col in col_lags:
    for month in month_lags:
        new_col = '{:} (-{:})'.format(col, month)
        data_df[new_col] = data_df.sort_values('date_block_num').groupby(['shop_id', 'item_id'])[col].shift(month)
        data_df[new_col] = data_df[new_col].fillna(0.0)
                    
data_df.head(2).T
# Out:
#                                                               0            1
# date_block_num                                         0.000000     0.000000
# shop_id                                               59.000000    25.000000
# item_id                                            22154.000000  2574.000000
# item_price                                           999.000000   399.000000
# date (year)                                         2013.000000  2013.000000
# date (month)                                           1.000000     1.000000
# date (days in month)                                  31.000000    31.000000
# ID                                                     0.000000     0.000000
# item_cnt_month                                         1.000000    13.000000
# item_category_id                                      37.000000    55.000000
# cat_name (code)                                        7.000000     8.000000
# category_type                                         11.000000    13.000000
# category_subtype                                       1.000000     2.000000
# shop_loc (code)                                       31.000000    14.000000
# date (holiday season)                                  0.000000     0.000000
# item_price (unit)                                    999.000000    30.000000
# shop (first sale)                                      0.000000     0.000000
# item_cnt_mef (date_block_num)                          5.762740     5.762740
# item_cnt_mef (month)                                   5.453773     5.453773
# item_cnt_mef (year)                                    6.339588     6.339588
# item_cat_cnt_mef (date_block_num)                      4.176064     2.876270
# item_cat_cnt_mef (month)                               3.154259     2.407457
# cat_name_cnt_mef (month)                               4.223237     2.339263
# cat_name_shop_cnt_mef (month)                               NaN          NaN
# cat_name_shop_cnt_mef (date_block_num)                      NaN          NaN
# shop_loc_cnt_mef (date_block_num)                      4.761786     6.827928
# shop_loc_item_cnt_mef (date_block_num)                 1.000000     9.115385
# shop_loc_cat_cnt_mef (date_block_num)                  2.760563     4.067557
# shop_loc_item_cat_cnt_mef (date_block_num)             1.090909     4.470698
# shop_item_price (date_block_num)                     999.000000   399.000000
# item_price (date_block_num)                          999.000000   392.564545
# cat_type_item_cnt_month (date_block_num)               5.121027     2.761373
# cat_subtype_item_cnt_month (date_block_num)            3.797834     2.876270
# item_cnt_month (-1)                                    0.000000    13.000000
# item_cnt_month (-2)                                    0.000000    13.000000
# item_cnt_month (-3)                                    0.000000    13.000000
# item_cnt_month (-6)                                    0.000000    13.000000
# item_cnt_month (-12)                                   0.000000     0.000000
# item_price (date_block_num) (-1)                       0.000000   392.564545
# item_price (date_block_num) (-2)                       0.000000   392.564545
# item_price (date_block_num) (-3)                       0.000000   392.564545
# item_price (date_block_num) (-6)                       0.000000   392.564545
# item_price (date_block_num) (-12)                      0.000000     0.000000
# shop_item_price (date_block_num) (-1)                  0.000000   399.000000
# shop_item_price (date_block_num) (-2)                  0.000000   399.000000
# shop_item_price (date_block_num) (-3)                  0.000000   399.000000
# shop_item_price (date_block_num) (-6)                  0.000000   399.000000
# shop_item_price (date_block_num) (-12)                 0.000000     0.000000
# item_cnt_mef (date_block_num) (-1)                     0.000000     5.762740
# item_cnt_mef (date_block_num) (-2)                     0.000000     5.762740
# item_cnt_mef (date_block_num) (-3)                     0.000000     5.762740
# item_cnt_mef (date_block_num) (-6)                     0.000000     5.762740
# item_cnt_mef (date_block_num) (-12)                    0.000000     0.000000
# item_cat_cnt_mef (date_block_num) (-1)                 0.000000     2.876270
# item_cat_cnt_mef (date_block_num) (-2)                 0.000000     2.876270
# item_cat_cnt_mef (date_block_num) (-3)                 0.000000     2.876270
# item_cat_cnt_mef (date_block_num) (-6)                 0.000000     2.876270
# item_cat_cnt_mef (date_block_num) (-12)                0.000000     0.000000
# cat_name_shop_cnt_mef (date_block_num) (-1)            0.000000     0.000000
# cat_name_shop_cnt_mef (date_block_num) (-2)            0.000000     0.000000
# cat_name_shop_cnt_mef (date_block_num) (-3)            0.000000     0.000000
# cat_name_shop_cnt_mef (date_block_num) (-6)            0.000000     0.000000
# cat_name_shop_cnt_mef (date_block_num) (-12)           0.000000     0.000000
# shop_loc_cnt_mef (date_block_num) (-1)                 0.000000     6.827928
# shop_loc_cnt_mef (date_block_num) (-2)                 0.000000     6.827928
# shop_loc_cnt_mef (date_block_num) (-3)                 0.000000     6.827928
# shop_loc_cnt_mef (date_block_num) (-6)                 0.000000     6.827928
# shop_loc_cnt_mef (date_block_num) (-12)                0.000000     0.000000
# shop_loc_item_cnt_mef (date_block_num) (-1)            0.000000     9.115385
# shop_loc_item_cnt_mef (date_block_num) (-2)            0.000000     9.115385
# shop_loc_item_cnt_mef (date_block_num) (-3)            0.000000     9.115385
# shop_loc_item_cnt_mef (date_block_num) (-6)            0.000000     9.115385
# shop_loc_item_cnt_mef (date_block_num) (-12)           0.000000     0.000000
# shop_loc_item_cat_cnt_mef (date_block_num) (-1)        0.000000     4.470698
# shop_loc_item_cat_cnt_mef (date_block_num) (-2)        0.000000     4.470698
# shop_loc_item_cat_cnt_mef (date_block_num) (-3)        0.000000     4.470698
# shop_loc_item_cat_cnt_mef (date_block_num) (-6)        0.000000     4.470698
# shop_loc_item_cat_cnt_mef (date_block_num) (-12)       0.000000     0.000000
# shop_loc_cat_cnt_mef (date_block_num) (-1)             0.000000     4.067557
# shop_loc_cat_cnt_mef (date_block_num) (-2)             0.000000     4.067557
# shop_loc_cat_cnt_mef (date_block_num) (-3)             0.000000     4.067557
# shop_loc_cat_cnt_mef (date_block_num) (-6)             0.000000     4.067557
# shop_loc_cat_cnt_mef (date_block_num) (-12)            0.000000     0.000000
# cat_type_item_cnt_month (date_block_num) (-1)          0.000000     2.761373
# cat_type_item_cnt_month (date_block_num) (-2)          0.000000     2.761373
# cat_type_item_cnt_month (date_block_num) (-3)          0.000000     2.761373
# cat_type_item_cnt_month (date_block_num) (-6)          0.000000     2.761373
# cat_type_item_cnt_month (date_block_num) (-12)         0.000000     0.000000
# cat_subtype_item_cnt_month (date_block_num) (-1)       0.000000     2.876270
# cat_subtype_item_cnt_month (date_block_num) (-2)       0.000000     2.876270
# cat_subtype_item_cnt_month (date_block_num) (-3)       0.000000     2.876270
# cat_subtype_item_cnt_month (date_block_num) (-6)       0.000000     2.876270
# cat_subtype_item_cnt_month (date_block_num) (-12)      0.000000     0.000000

# %%
data_df = data_df.fillna(0.0)

# %%
train_df = data_df[
    (data_df['date_block_num'] > 11) & 
    (data_df['date_block_num'] < 33)
]
test_df = data_df[data_df['date_block_num'] == 33]
pred_df = data_df[data_df['date_block_num'] == 34]

print('  Training rows:  {:,}'.format(len(train_df)))
print('   Testing rows:  {:,}'.format(len(test_df)))
print('Prediction rows:  {:,}'.format(len(pred_df)))
# Out:
#   Training rows:  994,949
#    Testing rows:  152,328
# Prediction rows:  214,200

# %%
del data_df, shops_df, items_df, item_categories_df

gc.collect()
# Out:
# 232

# %%
cols_to_drop = ['ID', 'item_cnt_month', 'item_price']

X_train = train_df.drop(cols_to_drop, axis=1)
y_train = train_df['item_cnt_month']

X_test = test_df.drop(cols_to_drop, axis=1)
y_test = test_df['item_cnt_month']

X_pred = pred_df.drop(cols_to_drop, axis=1)

X_pred.head(2).T
# Out:
#                                                        1436504      1436505
# date_block_num                                       34.000000    34.000000
# shop_id                                               5.000000     5.000000
# item_id                                            5037.000000  5320.000000
# date (year)                                        2015.000000  2015.000000
# date (month)                                         11.000000    11.000000
# date (days in month)                                 30.000000    30.000000
# item_category_id                                     19.000000    55.000000
# cat_name (code)                                       3.000000     8.000000
# category_type                                         5.000000    13.000000
# category_subtype                                     10.000000     2.000000
# shop_loc (code)                                       4.000000     4.000000
# date (holiday season)                                 0.000000     0.000000
# item_price (unit)                                     0.000000     0.000000
# shop (first sale)                                    14.000000     2.000000
# item_cnt_mef (date_block_num)                         0.000000     0.000000
# item_cnt_mef (month)                                  1.618390     1.618390
# item_cnt_mef (year)                                   2.272665     2.272665
# item_cat_cnt_mef (date_block_num)                     0.000000     0.000000
# item_cat_cnt_mef (month)                              2.924687     0.700693
# cat_name_cnt_mef (month)                              3.150010     0.557745
# cat_name_shop_cnt_mef (month)                         0.802536     0.000000
# cat_name_shop_cnt_mef (date_block_num)                0.000000     0.000000
# shop_loc_cnt_mef (date_block_num)                     0.000000     0.000000
# shop_loc_item_cnt_mef (date_block_num)                0.000000     0.000000
# shop_loc_cat_cnt_mef (date_block_num)                 0.000000     0.000000
# shop_loc_item_cat_cnt_mef (date_block_num)            0.000000     0.000000
# shop_item_price (date_block_num)                      0.000000     0.000000
# item_price (date_block_num)                         606.738098     0.000000
# cat_type_item_cnt_month (date_block_num)              0.000000     0.000000
# cat_subtype_item_cnt_month (date_block_num)           0.000000     0.000000
# item_cnt_month (-1)                                   1.000000     0.000000
# item_cnt_month (-2)                                   3.000000     0.000000
# item_cnt_month (-3)                                   3.000000     0.000000
# item_cnt_month (-6)                                   1.000000     0.000000
# item_cnt_month (-12)                                  1.000000     0.000000
# item_price (date_block_num) (-1)                    917.552612     0.000000
# item_price (date_block_num) (-2)                    890.383179     0.000000
# item_price (date_block_num) (-3)                    890.383179     0.000000
# item_price (date_block_num) (-6)                   1340.490234     0.000000
# item_price (date_block_num) (-12)                  2582.854492     0.000000
# shop_item_price (date_block_num) (-1)               749.500000     0.000000
# shop_item_price (date_block_num) (-2)               999.166687     0.000000
# shop_item_price (date_block_num) (-3)               999.166687     0.000000
# shop_item_price (date_block_num) (-6)              1499.000000     0.000000
# shop_item_price (date_block_num) (-12)             2599.000000     0.000000
# item_cnt_mef (date_block_num) (-1)                    1.335078     1.362927
# item_cnt_mef (date_block_num) (-2)                    3.912292     1.335078
# item_cnt_mef (date_block_num) (-3)                    3.912292     0.000000
# item_cnt_mef (date_block_num) (-6)                    4.270760     0.000000
# item_cnt_mef (date_block_num) (-12)                   5.923620     0.000000
# item_cat_cnt_mef (date_block_num) (-1)                3.091525     0.872921
# item_cat_cnt_mef (date_block_num) (-2)                4.357251     0.606961
# item_cat_cnt_mef (date_block_num) (-3)                4.357251     0.000000
# item_cat_cnt_mef (date_block_num) (-6)                3.313303     0.000000
# item_cat_cnt_mef (date_block_num) (-12)               4.549136     0.000000
# cat_name_shop_cnt_mef (date_block_num) (-1)           0.200787     0.000000
# cat_name_shop_cnt_mef (date_block_num) (-2)           6.391304     0.000000
# cat_name_shop_cnt_mef (date_block_num) (-3)           6.391304     0.000000
# cat_name_shop_cnt_mef (date_block_num) (-6)           6.432433     0.000000
# cat_name_shop_cnt_mef (date_block_num) (-12)          7.918919     0.000000
# shop_loc_cnt_mef (date_block_num) (-1)                0.883387     0.882472
# shop_loc_cnt_mef (date_block_num) (-2)                3.501333     0.883387
# shop_loc_cnt_mef (date_block_num) (-3)                3.501333     0.000000
# shop_loc_cnt_mef (date_block_num) (-6)                3.047739     0.000000
# shop_loc_cnt_mef (date_block_num) (-12)               4.834177     0.000000
# shop_loc_item_cnt_mef (date_block_num) (-1)           1.000000     0.000000
# shop_loc_item_cnt_mef (date_block_num) (-2)           3.000000     0.000000
# shop_loc_item_cnt_mef (date_block_num) (-3)           3.000000     0.000000
# shop_loc_item_cnt_mef (date_block_num) (-6)           1.000000     0.000000
# shop_loc_item_cnt_mef (date_block_num) (-12)          1.000000     0.000000
# shop_loc_item_cat_cnt_mef (date_block_num) (-1)       3.047619     0.602510
# shop_loc_item_cat_cnt_mef (date_block_num) (-2)       5.007936     0.476852
# shop_loc_item_cat_cnt_mef (date_block_num) (-3)       5.007936     0.000000
# shop_loc_item_cat_cnt_mef (date_block_num) (-6)       2.984375     0.000000
# shop_loc_item_cat_cnt_mef (date_block_num) (-12)      4.260000     0.000000
# shop_loc_cat_cnt_mef (date_block_num) (-1)            1.614914     0.250000
# shop_loc_cat_cnt_mef (date_block_num) (-2)            3.789030     0.200000
# shop_loc_cat_cnt_mef (date_block_num) (-3)            3.789030     0.000000
# shop_loc_cat_cnt_mef (date_block_num) (-6)            3.289308     0.000000
# shop_loc_cat_cnt_mef (date_block_num) (-12)           6.175676     0.000000
# cat_type_item_cnt_month (date_block_num) (-1)         3.169451     0.499276
# cat_type_item_cnt_month (date_block_num) (-2)         4.015118     0.374833
# cat_type_item_cnt_month (date_block_num) (-3)         4.015118     0.000000
# cat_type_item_cnt_month (date_block_num) (-6)         4.056139     0.000000
# cat_type_item_cnt_month (date_block_num) (-12)        6.036067     0.000000
# cat_subtype_item_cnt_month (date_block_num) (-1)      2.978962     0.872921
# cat_subtype_item_cnt_month (date_block_num) (-2)      4.321411     0.606961
# cat_subtype_item_cnt_month (date_block_num) (-3)      4.321411     0.000000
# cat_subtype_item_cnt_month (date_block_num) (-6)      3.271655     0.000000
# cat_subtype_item_cnt_month (date_block_num) (-12)     4.446803     0.000000

# %%
xgb = XGBRegressor(seed=1, 
                   n_estimators=500,
                   max_depth=8,
                   min_child_weight=300,
                   eta=0.3,
                   subsample=0.8,
                   colsample_bytree=0.8
)

xgb.fit(X_train, 
        y_train, 
        eval_metric='rmse',  
        eval_set=[(X_train, y_train), (X_test, y_test)], 
        verbose=True, 
        early_stopping_rounds=10)
# Out:
# C:\Users\Craig\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# C:\Users\Craig\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\xgboost\core.py:588: FutureWarning: Series.base is deprecated and will be removed in a future version
#   data.base is not None and isinstance(data, np.ndarray) \
# [09:15:34] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:6.1612	validation_1-rmse:3.27411
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 10 rounds.
# [1]	validation_0-rmse:5.56703	validation_1-rmse:2.95247
# [2]	validation_0-rmse:5.02319	validation_1-rmse:2.66963
# [3]	validation_0-rmse:4.52953	validation_1-rmse:2.4171
# [4]	validation_0-rmse:4.09437	validation_1-rmse:2.18087
# [5]	validation_0-rmse:3.7028	validation_1-rmse:1.97683
# [6]	validation_0-rmse:3.34535	validation_1-rmse:1.79388
# [7]	validation_0-rmse:3.02456	validation_1-rmse:1.62445
# [8]	validation_0-rmse:2.74149	validation_1-rmse:1.47837
# [9]	validation_0-rmse:2.48468	validation_1-rmse:1.34533
# [10]	validation_0-rmse:2.24962	validation_1-rmse:1.2268
# [11]	validation_0-rmse:2.04656	validation_1-rmse:1.11695
# [12]	validation_0-rmse:1.86206	validation_1-rmse:1.02241
# [13]	validation_0-rmse:1.69573	validation_1-rmse:0.938572
# [14]	validation_0-rmse:1.54843	validation_1-rmse:0.861021
# [15]	validation_0-rmse:1.41917	validation_1-rmse:0.795849
# [202]	validation_0-rmse:0.293654	validation_1-rmse:0.215078
# [203]	validation_0-rmse:0.293112	validation_1-rmse:0.214765
# [204]	validation_0-rmse:0.292889	validation_1-rmse:0.214701
# [205]	validation_0-rmse:0.29267	validation_1-rmse:0.214418
# [206]	validation_0-rmse:0.292545	validation_1-rmse:0.214368
# [207]	validation_0-rmse:0.292367	validation_1-rmse:0.214319
# [208]	validation_0-rmse:0.292066	validation_1-rmse:0.214144
# [209]	validation_0-rmse:0.291846	validation_1-rmse:0.213547
# [210]	validation_0-rmse:0.291595	validation_1-rmse:0.213368
# [211]	validation_0-rmse:0.291432	validation_1-rmse:0.213305
# [212]	validation_0-rmse:0.291056	validation_1-rmse:0.213096
# [213]	validation_0-rmse:0.290645	validation_1-rmse:0.212991
# [214]	validation_0-rmse:0.290341	validation_1-rmse:0.212753
# [215]	validation_0-rmse:0.290021	validation_1-rmse:0.212368
# [216]	validation_0-rmse:0.289802	validation_1-rmse:0.212076
# [217]	validation_0-rmse:0.289579	validation_1-rmse:0.211957
# [218]	validation_0-rmse:0.289471	validation_1-rmse:0.21197
# [219]	validation_0-rmse:0.289153	validation_1-rmse:0.211941
# [220]	validation_0-rmse:0.288975	validation_1-rmse:0.211841
# [221]	validation_0-rmse:0.288898	validation_1-rmse:0.211838
# [222]	validation_0-rmse:0.288672	validation_1-rmse:0.211733
# [223]	validation_0-rmse:0.288401	validation_1-rmse:0.211673
# [224]	validation_0-rmse:0.288185	validation_1-rmse:0.211613
# [225]	validation_0-rmse:0.288012	validation_1-rmse:0.211466
# [226]	validation_0-rmse:0.287797	validation_1-rmse:0.211364
# [227]	validation_0-rmse:0.287616	validation_1-rmse:0.211277
# [228]	validation_0-rmse:0.287437	validation_1-rmse:0.21117
# [229]	validation_0-rmse:0.287252	validation_1-rmse:0.211185
# [230]	validation_0-rmse:0.287098	validation_1-rmse:0.211073
# [231]	validation_0-rmse:0.286961	validation_1-rmse:0.21108
# [232]	validation_0-rmse:0.286714	validation_1-rmse:0.211002
# [233]	validation_0-rmse:0.286544	validation_1-rmse:0.21094
# [234]	validation_0-rmse:0.286134	validation_1-rmse:0.210707
# [235]	validation_0-rmse:0.285921	validation_1-rmse:0.210497
# [236]	validation_0-rmse:0.285759	validation_1-rmse:0.21033
# [237]	validation_0-rmse:0.285562	validation_1-rmse:0.210025
# [238]	validation_0-rmse:0.285329	validation_1-rmse:0.210011
# [239]	validation_0-rmse:0.28512	validation_1-rmse:0.209845
# [240]	validation_0-rmse:0.284825	validation_1-rmse:0.209379
# [241]	validation_0-rmse:0.284677	validation_1-rmse:0.209287
# [242]	validation_0-rmse:0.28429	validation_1-rmse:0.208878
# [243]	validation_0-rmse:0.284073	validation_1-rmse:0.2088
# [244]	validation_0-rmse:0.283646	validation_1-rmse:0.208557
# [245]	validation_0-rmse:0.283445	validation_1-rmse:0.208437
# [246]	validation_0-rmse:0.28325	validation_1-rmse:0.208339
# [247]	validation_0-rmse:0.283021	validation_1-rmse:0.208298
# [248]	validation_0-rmse:0.28289	validation_1-rmse:0.207348
# [249]	validation_0-rmse:0.282503	validation_1-rmse:0.206669
# [250]	validation_0-rmse:0.282226	validation_1-rmse:0.206262
# [251]	validation_0-rmse:0.282118	validation_1-rmse:0.206273
# [252]	validation_0-rmse:0.281896	validation_1-rmse:0.205716
# [253]	validation_0-rmse:0.281726	validation_1-rmse:0.205633
# [254]	validation_0-rmse:0.281541	validation_1-rmse:0.205287
# [255]	validation_0-rmse:0.281339	validation_1-rmse:0.205138
# [256]	validation_0-rmse:0.281179	validation_1-rmse:0.205015
# [257]	validation_0-rmse:0.280979	validation_1-rmse:0.204818
# [258]	validation_0-rmse:0.280843	validation_1-rmse:0.20478
# [259]	validation_0-rmse:0.280529	validation_1-rmse:0.20468
# [260]	validation_0-rmse:0.280428	validation_1-rmse:0.206204
# [261]	validation_0-rmse:0.28037	validation_1-rmse:0.206167
# [262]	validation_0-rmse:0.28031	validation_1-rmse:0.206111
# [263]	validation_0-rmse:0.280129	validation_1-rmse:0.2061
# [264]	validation_0-rmse:0.279828	validation_1-rmse:0.20586
# [265]	validation_0-rmse:0.279549	validation_1-rmse:0.205551
# [266]	validation_0-rmse:0.279365	validation_1-rmse:0.205319
# [267]	validation_0-rmse:0.279316	validation_1-rmse:0.205311
# [268]	validation_0-rmse:0.279144	validation_1-rmse:0.205216
# [269]	validation_0-rmse:0.278946	validation_1-rmse:0.205158
# Stopping. Best iteration:
# [259]	validation_0-rmse:0.280529	validation_1-rmse:0.20468
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bynode=1, colsample_bytree=0.8, eta=0.3, gamma=0,
#        importance_type='gain', learning_rate=0.1, max_delta_step=0,
#        max_depth=8, min_child_weight=300, missing=None, n_estimators=500,
#        n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=1, silent=None,
#        subsample=0.8, verbosity=1)

# %%
plt.rcParams['figure.figsize'] = (20, 16)

plot_importance(xgb)

# %%
pred_df['item_cnt_month'] = xgb.predict(X_pred).clip(0, 20)

pred_df['ID'] = pred_df['ID'].astype(int)

pred_df[['ID', 'item_cnt_month']].to_csv('submissions/final_submission.csv', index=False)

# %%
bagged_df = pd.read_csv('submissions/submission-Oct-2015.csv')
bagged_df.head(5)
# Out:
#    ID  item_cnt_month
# 0   0             0.0
# 1   1             0.0
# 2   2             1.0
# 3   3             0.0
# 4   4             0.0

# %%
bagged_df = bagged_df.merge(pred_df[['ID', 'item_cnt_month']], on='ID')
bagged_df.head(5)
# Out:
#    ID  item_cnt_month_x  item_cnt_month_y
# 0   0               0.0          0.953654
# 1   1               0.0          0.000000
# 2   2               1.0          0.004585
# 3   3               0.0          0.113660
# 4   4               0.0          0.000204

# %%
bagged_df['item_cnt_month'] = (bagged_df['item_cnt_month_x'] + bagged_df['item_cnt_month_y']) / 2
bagged_df[['ID', 'item_cnt_month']].to_csv('./submissions/bagged-avg.csv', index=False)

# %%
def bagged_or(row):
    return 0 if row['item_cnt_month_x'] == 0.0 else row['item_cnt_month_y']
    
bagged_df['item_cnt_month'] = bagged_df.apply(lambda row: bagged_or(row), axis=1
                                             )
bagged_df[['ID', 'item_cnt_month']].to_csv('./submissions/bagged-or.csv', index=False)
